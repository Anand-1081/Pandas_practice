# %%
import numpy as np 
import pandas as pd

# %%
# Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    324     56   John  January      Q1
# 1  2023-01-02       B   West    935     77   Mary  January      Q1
# 2  2023-01-03       C  North    617     51    Bob  January      Q1
# 3  2023-01-04       D  South    666     43  Alice  January      Q1
# 4  2023-01-05       A   East    214     68   John  January      Q1
# 5  2023-01-06       B   West    955     70   Mary  January      Q1
# 6  2023-01-07       C  North    662     33    Bob  January      Q1
# 7  2023-01-08       D  South    535     16  Alice  January      Q1
# 8  2023-01-09       A   East    603     73   John  January      Q1
# 9  2023-01-10       B   West    404     93   Mary  January      Q1
# 10 2023-01-11       C  North    358     96    Bob  January      Q1
# 11 2023-01-12       D  South    982     75  Alice  January      Q1
# 12 2023-01-13       A   East    127     94   John  January      Q1
# 13 2023-01-14       B   West    829     52   Mary  January      Q1
# 14 2023-01-15       C  North    464     46    Bob  January      Q1
# 15 2023-01-16       D  South    345     29  Alice  January      Q1
# 16 2023-01-17       A   East    193     11   John  January      Q1
# 17 2023-01-18       B   West    390     58   Mary  January      Q1
# 18 2023-01-19       C  North    656     94    Bob  January      Q1
# 19 2023-01-20       D  South    273     76  Alice  January      Q1

# %%
pd.pivot_table(df, values='Sales',index='Region' , columns='Product')
# Out:
# Product      A      B      C      D
# Region
# East     292.2    NaN    NaN    NaN
# North      NaN    NaN  551.4    NaN
# South      NaN    NaN    NaN  560.2
# West       NaN  702.6    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     292.2    NaN    NaN    NaN  60.4   NaN   NaN   NaN
# North      NaN    NaN  551.4    NaN   NaN   NaN  64.0   NaN
# South      NaN    NaN    NaN  560.2   NaN   NaN   NaN  47.8
# West       NaN  702.6    NaN    NaN   NaN  70.0   NaN   NaN

# %%
# Cross Tabs

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
