# %%
# Pandas series
# A series is one - dimentional labeled array capable of holding any data type .
# the axis lables are  collectively called the index

# %%
# creating series
# there are multipple ways to create a panda series

# %%
import numpy as np
import pandas as pd
# in Series you can only give one dimensional array

# %%
labels = ['a','b','c']
list = [10,20,30]
arr = np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(list, index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
